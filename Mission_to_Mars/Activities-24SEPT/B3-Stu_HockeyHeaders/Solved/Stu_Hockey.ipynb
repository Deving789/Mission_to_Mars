# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Stars seek 'different level' in Game 4 of Cup Final
# Top players know they need to be better to even series against Lightning
# 2020-09-24
# -----------------
# Lightning, Stars eyeing Game 4 of Cup Final rather than back-to-back
# Game 5 thoughts can wait with Tampa Bay aiming to extend series lead against Dallas
# 2020-09-24
# -----------------
# Hornqvist traded to Panthers by Penguins for Matheson, Sceviour
# Forward, two-time Cup winner with Pittsburgh, acquired for defenseman, center
# 2020-09-24
# -----------------
# Hedman closing in on history for Lightning entering Game 4 of Cup Final
# Two away from goals record for defenseman in single postseason, has grown into 'beast'
# 2020-09-24
# -----------------
# Stamkos' brief stint enough to inspire Lightning in Game 3 win
# Scores in return before leaving in first to help take lead in Cup Final against Stars
# 2020-09-24
# -----------------
# Stanley Cup Final schedule
# Will be played in Edmonton, includes back-to-back Games 4-5
# 2020-09-23
# -----------------
# Toffoli among top potential unrestricted free agents, statistics show
# Pietrangelo, Khudobin also stand out on list of players who could sign with new teams Oct. 9
# 2020-09-24
# -----------------
# Mullen, Modano watching Pavelski chase record for Stars in Cup Final
# Hall of Famers hope forward scores most postseason goals by U.S.-born player
# 2020-09-24
# -----------------
# Fleury wants to stay with Golden Knights even if they sign Lehner: report
# Goalie was backup to pending unrestricted free agent during postseason
# 2020-09-24
# -----------------
# NHL announces protocols for offseason training
# Start dates for training camp, 2020-21 regular season not set
# 2020-09-24
# -----------------
# Stamkos, Hedman among top performers for Lightning in Game 3 of Cup Final
# Honor roll, stock watch from Tampa Bay's win against Stars
# 2020-09-23
# -----------------
# Esposito, Gainey celebrate legacies with Stars, Lightning in Cup Final
# Hall of Famers helped build foundations for success in Dallas, Tampa Bay
# 2020-09-24
# -----------------
# Stanley Cup Final blog: Jake Oettinger
# Stars backup goalie discusses playing in Game 3 loss to Lightning
# 2020-09-24
# -----------------
# Stars 'not going to panic' after Game 3 loss in Cup Final
# Aware they got away from identity against Lightning but confident in ability to even series
# 2020-09-24
# -----------------
# NHL DFS picks, rankings for Stanley Cup Final
# Hedman tied for second on Lightning in goals, brings exposure to Kucherov, Point
# 2020-09-24
# -----------------
# 2019-20 NHL Trade Tracker
# Official deals since June 14, 2019
# 2020-09-24
# -----------------
# Fantasy offseason news, trades, signings roundup
# Trade could land Hornqvist on power play with Huberdeau, Barkov
# 2020-09-24
# -----------------
# 2020 Draft: Senators see three first-round picks as next step in rebuild
# Seven selections in top two rounds key in goal of returning to Stanley Cup Playoffs
# 2020-09-24
# -----------------
# Stars defense, discipline must improve in Game 4 of Stanley Cup Final
# Zettler says better power play also vital in bid to even series against Lightning
# 2020-09-24
# -----------------
# Facts and Figures: Hedman chasing history for Lightning in Cup Final
# Three goals from NHL record for most in one postseason by defenseman; Tampa Bay leads series 2-1
# 2020-09-24
# -----------------
# Mailbag: Pietrangelo as free agent, Stamkos' standing with Lightning
# NHL.com's Dan Rosen answers weekly questions
# 2020-09-23
# -----------------
# Coyotes would need to be 'very creative' to sign Hall, GM says
# Arizona plans to 'explore everything' with pending free agent forward
# 2020-09-23
# -----------------
# Lightning use surge in second period to win Game 3 of Stanley Cup Final
# Take control with three unanswered goals against Stars
# 2020-09-24
# -----------------
# Stamkos scores for Lightning in Game 3 win against Stars in Cup Final
# Forward, playing for first time since Feb. 25, leaves game late in first period
# 2020-09-24
# -----------------
# Olson to receive Lester Patrick Trophy
# Women's hockey pioneer will be honored at U.S. Hockey Hall of Fame induction celebration
# 2020-09-24
# -----------------
# NHL award winners handicap races for next season
# Draisaitl sees McDavid, MacKinnon in Hart Trophy hunt; Josi says Makar, Hughes could win Norris
# 2020-09-22
# -----------------
# Stanley Cup Final Game 3 Live Blog: Lightning vs. Stars
# Sights, sounds from Tampa Bay's 5-2 win against Dallas
# 2020-09-23
# -----------------
# Anderson won't return to Senators next season
# 39-year-old goalie, Ottawa's leader in wins, to become free agent
# 2020-09-23
# -----------------
# 2020 Draft: Devils expect to improve with three picks in first round
# Look to add talent to young group that includes Hischier, Hughes
# 2020-09-23
# -----------------
# Sept. 24: Canada wins Game 6 of Summit Series
# Plus: NHL adopts icing rule; Stevens named captain of Devils
# 2020-09-24

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb919'), 'header': "Stars seek 'different level' in Game 4 of Cup Final", 'subheader': 'Top players know they need to be better to even series against Lightning', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb91a'), 'header': 'Lightning, Stars eyeing Game 4 of Cup Final rather than back-to-back', 'subheader': 'Game 5 thoughts can wait with Tampa Bay aiming to extend series lead against Dallas', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb91b'), 'header': 'Hornqvist traded to Panthers by Penguins for Matheson, Sceviour', 'subheader': 'Forward, two-time Cup winner with Pittsburgh, acquired for defenseman, center', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb91c'), 'header': 'Hedman closing in on history for Lightning entering Game 4 of Cup Final', 'subheader': "Two away from goals record for defenseman in single postseason, has grown into 'beast'", 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb91d'), 'header': "Stamkos' brief stint enough to inspire Lightning in Game 3 win", 'subheader': 'Scores in return before leaving in first to help take lead in Cup Final against Stars', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb91e'), 'header': 'Stanley Cup Final schedule', 'subheader': 'Will be played in Edmonton, includes back-to-back Games 4-5', 'date': '2020-09-23'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb91f'), 'header': 'Toffoli among top potential unrestricted free agents, statistics show', 'subheader': 'Pietrangelo, Khudobin also stand out on list of players who could sign with new teams Oct. 9', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb920'), 'header': 'Mullen, Modano watching Pavelski chase record for Stars in Cup Final', 'subheader': 'Hall of Famers hope forward scores most postseason goals by U.S.-born player', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb921'), 'header': 'Fleury wants to stay with Golden Knights even if they sign Lehner: report', 'subheader': 'Goalie was backup to pending unrestricted free agent during postseason', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb922'), 'header': 'NHL announces protocols for offseason training', 'subheader': 'Start dates for training camp, 2020-21 regular season not set', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb923'), 'header': 'Stamkos, Hedman among top performers for Lightning in Game 3 of Cup Final', 'subheader': "Honor roll, stock watch from Tampa Bay's win against Stars", 'date': '2020-09-23'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb924'), 'header': 'Esposito, Gainey celebrate legacies with Stars, Lightning in Cup Final', 'subheader': 'Hall of Famers helped build foundations for success in Dallas, Tampa Bay', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb925'), 'header': 'Stanley Cup Final blog: Jake Oettinger', 'subheader': 'Stars backup goalie discusses playing in Game 3 loss to Lightning', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb926'), 'header': "Stars 'not going to panic' after Game 3 loss in Cup Final", 'subheader': 'Aware they got away from identity against Lightning but confident in ability to even series', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb927'), 'header': 'NHL DFS picks, rankings for Stanley Cup Final', 'subheader': 'Hedman tied for second on Lightning in goals, brings exposure to Kucherov, Point', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb928'), 'header': '2019-20 NHL Trade Tracker', 'subheader': 'Official deals since June 14, 2019', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb929'), 'header': 'Fantasy offseason news, trades, signings roundup', 'subheader': 'Trade could land Hornqvist on power play with Huberdeau, Barkov', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb92a'), 'header': '2020 Draft: Senators see three first-round picks as next step in rebuild', 'subheader': 'Seven selections in top two rounds key in goal of returning to Stanley Cup Playoffs', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb92b'), 'header': 'Stars defense, discipline must improve in Game 4 of Stanley Cup Final', 'subheader': 'Zettler says better power play also vital in bid to even series against Lightning', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb92c'), 'header': 'Facts and Figures: Hedman chasing history for Lightning in Cup Final', 'subheader': 'Three goals from NHL record for most in one postseason by defenseman; Tampa Bay leads series 2-1', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb92d'), 'header': "Mailbag: Pietrangelo as free agent, Stamkos' standing with Lightning", 'subheader': "NHL.com's Dan Rosen answers weekly questions", 'date': '2020-09-23'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb92e'), 'header': "Coyotes would need to be 'very creative' to sign Hall, GM says", 'subheader': "Arizona plans to 'explore everything' with pending free agent forward", 'date': '2020-09-23'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb92f'), 'header': 'Lightning use surge in second period to win Game 3 of Stanley Cup Final', 'subheader': 'Take control with three unanswered goals against Stars', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb930'), 'header': 'Stamkos scores for Lightning in Game 3 win against Stars in Cup Final', 'subheader': 'Forward, playing for first time since Feb. 25, leaves game late in first period', 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb931'), 'header': 'Olson to receive Lester Patrick Trophy', 'subheader': "Women's hockey pioneer will be honored at U.S. Hockey Hall of Fame induction celebration", 'date': '2020-09-24'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb932'), 'header': 'NHL award winners handicap races for next season', 'subheader': 'Draisaitl sees McDavid, MacKinnon in Hart Trophy hunt; Josi says Makar, Hughes could win Norris', 'date': '2020-09-22'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb933'), 'header': 'Stanley Cup Final Game 3 Live Blog: Lightning vs. Stars', 'subheader': "Sights, sounds from Tampa Bay's 5-2 win against Dallas", 'date': '2020-09-23'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb934'), 'header': "Anderson won't return to Senators next season", 'subheader': "39-year-old goalie, Ottawa's leader in wins, to become free agent", 'date': '2020-09-23'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb935'), 'header': '2020 Draft: Devils expect to improve with three picks in first round', 'subheader': 'Look to add talent to young group that includes Hischier, Hughes', 'date': '2020-09-23'}
# {'_id': ObjectId('5f6d338f0a5cbc8bf1fbb936'), 'header': 'Sept. 24: Canada wins Game 6 of Summit Series', 'subheader': 'Plus: NHL adopts icing rule; Stevens named captain of Devils', 'date': '2020-09-24'}
